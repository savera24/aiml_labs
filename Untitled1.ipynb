# %% [markdown]
# <a href="https://colab.research.google.com/github/savera24/aiml_labs/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter a number:"))
if(a%5==0):
  print("Number is divisible by 5")
# Out:
# enter a number:5
# Number is divisible by 5

# %%
# Initial facts
facts = {"Fever", "Cough"}

# Rules: (conditions, result)
rules = [
    ({"Fever", "Cough"}, "Flu"),
    ({"Flu"}, "Doctor_Visit")
]

print("Initial Facts:", facts)

changed = True
while changed:
    changed = False
    for condition, result in rules:
        # Check if rule can be applied
        if condition.issubset(facts) and result not in facts:
            facts.add(result)
            print("New fact inferred:", result)
            changed = True

print("Final Facts:", facts)
# Out:
# Initial Facts: {'Fever', 'Cough'}
# New fact inferred: Flu
# New fact inferred: Doctor_Visit
# Final Facts: {'Fever', 'Flu', 'Doctor_Visit', 'Cough'}

# %%
a=int(input("enter marks"))
if(a>=85):
  print("eligible for scholarship")
# Out:
# enter marks90
# eligible for scholarship

# %%
a=int(input("enter a number"))
if(a<0):
  print("Negative number")
else:
  print("positive number")
# Out:
# enter a number9
# positive number

# %%
a=input()
if(a=="green"):
  print("go")
elif(a=="yellow"):
  print("ready")
elif(a=="red"):
  print("stop")
# Out:
# green
# go

# %%
a=float(input("enter units consumed"))
rpu=
c=rpu*a
if(c<)

# %%
a=input()
b=int(input())
c=float(input())
d=input()
print("Name:",a)
print("Age:",b)
print("CGPA: {:.2f}".format(c))
print("Grade:",d)
# Out:
# s
# 1
# 8.93
# a
# Name: s
# Age: 1
# CGPA: 8.93
# Grade: a

# %%
import math
m=float(input("Enter first number:"))
n=float(input("Enter second number:"))
print(math.sqrt(m))
print(math.sqrt(n))
print(math.pow(m,n))
print(abs(m))
print(abs(n))
# Out:
# Enter first number:2
# Enter second number:2
# 1.4142135623730951
# 1.4142135623730951
# 4.0
# 2.0
# 2.0

# %%
import matplotlib.pyplot as plt
data=[5,7,8,7,6,9,10,6,5,8,9,7]
plt.hist(data,bins=6,color="purple",edgecolor="black")
plt.xlabel("temperature")
plt.ylabel("humidity")
plt.title("weather")
# Out:
# Text(0.5, 1.0, 'weather')

# %%
import statistics
data=[10,20,30,40,50]
mean_data=statistics.mean(data)
median_data=statistics.median(data)
mode_data=statistics.mode(data)
standard_deviation=statistics.stdev(data)
variance_data=statistics.variance(data)
print(mean_data,end=" ,")
print(median_data,end=" ,")
print(mode_data,end=", ")
print(standard_deviation,end=" ,")
print(variance_data)
# Out:
# 30 ,30 ,10, 15.811388300841896 ,250

# %%
import numpy as np
from scipy import stats
data = [10, 11, 12, 10, 11, 12, 11, 10, 12, 10, 11, 12, 10, 11, 12, 100]
z_scores = stats.zscore(data)
outliers = [data[i] for i in range(len(data)) if abs(z_scores[i]) > 3]

print("Z-scores:", z_scores)
print("Outliers:", outliers)
# Out:
# Z-scores: [-0.30441177 -0.25802522 -0.21163866 -0.30441177 -0.25802522 -0.21163866
#  -0.25802522 -0.30441177 -0.21163866 -0.30441177 -0.25802522 -0.21163866
#  -0.30441177 -0.25802522 -0.21163866  3.87037824]
# Outliers: [100]

# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
row=df.loc[0:9]
print(row)
# Out:
#    Sl no     Product  price
# 0      1      Orange    100
# 1      2        Milk    200
# 2      3    Biscuits     40
# 3      4  Chocolates     50
# 4      5        Ghee    250
# 5      6        Salt     10
# 6      7       Water    250
# 7      8      Carrot     60
# 8      9   Pineapple     40
# 9     10        Cake    100

# %%
import matplotlib.pyplot as plt
x=["carrot","potato","Tomato","brinjal","banana"]
y=[10,20,30,10,10]
plt.plot(x,y,color="pink")
plt.show()

# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', None],
    'Age': [25, np.nan, 30, 22, 28],
    'Salary': [50000, 60000, None, 45000, 52000]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
print("\nMissing values count:")
print(df.isnull().sum())
df_filled_constant = df.fillna("Unknown")
print("\nReplace with constant:")
print(df_filled_constant)
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df['Name'].fillna("NoName", inplace=True)

print("\nDataFrame after replacing missing values:")
print(df)
# Out:
# Original DataFrame:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  60000.0
# 2  Charlie  30.0      NaN
# 3    David  22.0  45000.0
# 4     None  28.0  52000.0
#
# Missing values count:
# Name      1
# Age       1
# Salary    1
# dtype: int64
#
# Replace with constant:
#       Name      Age   Salary
# 0    Alice     25.0  50000.0
# 1      Bob  Unknown  60000.0
# 2  Charlie     30.0  Unknown
# 3    David     22.0  45000.0
# 4  Unknown     28.0  52000.0
#
# DataFrame after replacing missing values:
#       Name    Age   Salary
# 0    Alice  25.00  50000.0
# 1      Bob  26.25  60000.0
# 2  Charlie  30.00  51750.0
# 3    David  22.00  45000.0
# 4   NoName  28.00  52000.0
# /tmp/ipython-input-2316823364.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(42)
data = {
    'Age': np.random.randint(20, 60, 50),
    'Salary': np.random.randint(30000, 100000, 50),
    'Experience': np.random.randint(1, 40, 50),
    'PerformanceScore': np.random.randint(1, 10, 50)
}

df = pd.DataFrame(data)
corr = df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
vowels="aeiouAEIOU"
count=0
a=(input("enter a string:"))
for i in range (len(a)):
  if a[i] in vowels:
    count+=1
print(count)
# Out:
# enter a string:ae
# 2
